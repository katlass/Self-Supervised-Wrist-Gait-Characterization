# %%
import os 
import pandas as pd
import re
from tqdm import tqdm
import numpy as np
from sklearn.metrics import f1_score, balanced_accuracy_score,precision_score, recall_score
import matplotlib.pyplot as plt

# %%
results_path = '/mnt/Jake/results_mobilise_ionescu_full_redo/'

# %%
subject_ids = [p for p in os.listdir(results_path) if p[0] != '.']

# %%
data_dir = "/domino/datasets/local/dataset/idea_fast/for_s3/"

# %%
def plot_lists(truth, predictions):
    indices = list(range(len(truth)))
    plt.figure(figsize=(10, 5))
    plt.plot(indices, truth, label='Truth', color='blue', marker='o', linestyle='-', markersize=6)
    plt.plot(indices, predictions, label='Predictions', color='red', marker='x', linestyle='--', markersize=6)
    plt.title('Truth vs Predictions')
    plt.xlabel('Index')
    plt.ylabel('0 or 1')
    plt.grid(True)

    plt.show()

# %%
len_guess = 119790
examples_seen = 1
f1s = {}
import os
import re
import pandas as pd

import os
import re
import pandas as pd

def process_single_subject(subjects_dir, subject_folder):
    """
    Process CSV files for a single subject folder and return the concatenated data.

    Parameters:
    - subjects_dir (str): Path to the directory containing subject folders.
    - subject_folder (str): The name of the specific subject folder to process.

    Returns:
    - pd.DataFrame: Concatenated DataFrame of all relevant CSV data for the subject, 
      or None if there are no relevant files or an error occurs.
    """
    subject_path = os.path.join(subjects_dir, subject_folder)
    
    # Ensure it's a directory
    if not os.path.isdir(subject_path):
        print(f"{subject_folder} is not a valid directory.")
        return None
    
    print(f"\nProcessing subject folder: {subject_folder}")
    
    # Find relevant CSV files in the folder based on the pattern
    csv_files = [
        f for f in os.listdir(subject_path)
        if re.match(rf"{subject_folder}-\w{{9}}-\d{{8}}-\d{{8}}_omx_mapped_mapped\.csv", f)
    ]
    
    # Check if any CSV files were found
    if not csv_files:
        print(f"No relevant CSV files found in {subject_folder}.")
        return None
    
    print(f"Found {len(csv_files)} relevant CSV file(s): {csv_files}")
    
    # Initialize an empty list to store data from each file
    subject_data = []

    
    # Process each relevant CSV file
    for csv_file in csv_files:
        file_path = os.path.join(subject_path, csv_file)
        print(f"Processing file: {csv_file}")
        df = pd.read_csv(file_path)
        # Preprocess the file and append the data
        
        subject_data.append(df)
    
    # Concatenate subject_data into one DataFrame if there is data
    if subject_data:
        all_data = pd.concat(subject_data, ignore_index=True)
        print(f"Concatenated data for {subject_folder} with {len(all_data)} rows.")
        return all_data
    else:
        print(f"No data to concatenate for {subject_folder}.")
        return None

                
num_subjects = 0
for subject in subject_ids:
    print(f"Loading {subject} labels...")
    label_list = []
    try:
        label_list = process_single_subject(data_dir, subject)['mapped_value'].values
        num_subjects +=1
    except:
        continue
    label_list = process_single_subject(data_dir, subject)['mapped_value'].values
    """with pd.read_csv(data_dir + subject + '/mapped_df.csv', chunksize=1000) as label_reader:
        chunk_counter = 0
        for chunk in tqdm(label_reader, total=len_guess):
            chunk_counter += 1
            label_list.extend(pd.DataFrame(chunk)['mapped_value'].values)"""
    #examples_seen += 1
    #len_guess = (len_guess + chunk_counter) / examples_seen

    label_series = pd.Series(label_list)
    #print("Outputting label distribution...")
    #print(label_series.value_counts())
    activity_mapping = {
        'not_worn':0,
        'lying':0,
        'standing':0,        
        'sitting':0,
        'walking':1,
        'running':1,
        'shuffling':1,
        'stair_walking':1
    }
    
    truth_list = label_series.map(activity_mapping).fillna(0).astype(int).tolist()
    
    pred_idx_df = pd.read_csv(results_path + subject + '/gs_list.csv')
    pred_list = [0] * (len(label_list))
    for ix, row in pred_idx_df.iterrows():
        pred_list[row['start']:row['end']+1] = [1] * (row['end']-row['start']+1)
    diff = 0
    truth_array = np.array(truth_list)
    pred_array = np.array(pred_list)
    matching_indices = np.where(truth_array == pred_array)[0]
    print("accuracy: ", len(matching_indices)/len(pred_array), "num matches: " ,len(matching_indices))
    print("matches at: ", matching_indices)
    if len(truth_list) == len(pred_list):
        f1 = f1_score(truth_list, pred_list)
        precision = precision_score(truth_list, pred_list)
        recall = recall_score(truth_list, pred_list)
        accuracy = balanced_accuracy_score(truth_list, pred_list)
        
        #plot_lists(truth_list, pred_list)
    else:
        diff = len(truth_list) - len(pred_list)
        print(f"Misalignment of {diff} between truth and prediction detected!")
        if diff < 0:
            diff = abs(diff)
            f1_trim_front = f1_score(truth_list, pred_list[diff:])
            f1_trim_back = f1_score(truth_list, pred_list[:-diff])
            
            accuracy_trim_front = balanced_accuracy_score(truth_list, pred_list[diff:])
            accuracy_trim_back = balanced_accuracy_score(truth_list, pred_list[:-diff])
            
            #plot_lists(truth_list, pred_list[diff:])
        else:
            f1_trim_front = f1_score(truth_list[diff:], pred_list)            
            f1_trim_back = f1_score(truth_list[:-diff], pred_list)
            
            accuracy_trim_front = balanced_accuracy_score(truth_list[diff:], pred_list)
            accuracy_trim_back = balanced_accuracy_score(truth_list[:-diff], pred_list)
            
            #plot_lists(truth_list[diff:], pred_list)
        
        f1 = max(f1_trim_front, f1_trim_back)
        accuracy = max(accuracy_trim_front, accuracy_trim_back)
    

    f1s[subject] = f1
    #print(f"The truth looks like: {pd.Series(truth_list).value_counts()}")
    #print(f"The predictions looks like: {pd.Series(pred_list).value_counts()}")
    print(f"Balanced Accuracy for {subject}: {f1:.2f}")
    print(f"F1 for {subject}: {f1:.2f}")
    print(f"Precision for {subject}: {precision:.2f}")
    print(f"Recall for {subject}: {recall:.2f}")
print(num_subjects)
# Out:
# Loading NNF2HPY labels...
#
# Processing subject folder: NNF2HPY
# Found 2 relevant CSV file(s): ['NNF2HPY-MMMZA3GVX-20210118-20210124_omx_mapped_mapped.csv', 'NNF2HPY-MMMXHG3EE-20210125-20210131_omx_mapped_mapped.csv']
# Processing file: NNF2HPY-MMMZA3GVX-20210118-20210124_omx_mapped_mapped.csv
# Processing file: NNF2HPY-MMMXHG3EE-20210125-20210131_omx_mapped_mapped.csv
# Concatenated data for NNF2HPY with 103680000 rows.
#
# Processing subject folder: NNF2HPY
# Found 2 relevant CSV file(s): ['NNF2HPY-MMMZA3GVX-20210118-20210124_omx_mapped_mapped.csv', 'NNF2HPY-MMMXHG3EE-20210125-20210131_omx_mapped_mapped.csv']
# Processing file: NNF2HPY-MMMZA3GVX-20210118-20210124_omx_mapped_mapped.csv
# Processing file: NNF2HPY-MMMXHG3EE-20210125-20210131_omx_mapped_mapped.csv
# Concatenated data for NNF2HPY with 103680000 rows.
# accuracy:  0.9702412422839506 num matches:  100594612
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for NNF2HPY: 0.77
# F1 for NNF2HPY: 0.77
# Precision for NNF2HPY: 0.72
# Recall for NNF2HPY: 0.83
# Loading N2GX64S labels...
#
# Processing subject folder: N2GX64S
# Found 2 relevant CSV file(s): ['N2GX64S-MMMSDZVXX-20012021-26012021_omx_mapped_mapped.csv', 'N2GX64S-MMMHYYZZQ-27012021-02022021_omx_mapped_mapped.csv']
# Processing file: N2GX64S-MMMSDZVXX-20012021-26012021_omx_mapped_mapped.csv
# Processing file: N2GX64S-MMMHYYZZQ-27012021-02022021_omx_mapped_mapped.csv
# Concatenated data for N2GX64S with 103680000 rows.
#
# Processing subject folder: N2GX64S
# Found 2 relevant CSV file(s): ['N2GX64S-MMMSDZVXX-20012021-26012021_omx_mapped_mapped.csv', 'N2GX64S-MMMHYYZZQ-27012021-02022021_omx_mapped_mapped.csv']
# Processing file: N2GX64S-MMMSDZVXX-20012021-26012021_omx_mapped_mapped.csv
# Processing file: N2GX64S-MMMHYYZZQ-27012021-02022021_omx_mapped_mapped.csv
# Concatenated data for N2GX64S with 103680000 rows.
# accuracy:  0.9759091628086419 num matches:  101182262
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for N2GX64S: 0.74
# F1 for N2GX64S: 0.74
# Precision for N2GX64S: 0.68
# Recall for N2GX64S: 0.81
# Loading NDRPH9Q labels...
#
# Processing subject folder: NDRPH9Q
# Found 1 relevant CSV file(s): ['NDRPH9Q-MMM666R4P-20210311-20210317_omx_mapped_mapped.csv']
# Processing file: NDRPH9Q-MMM666R4P-20210311-20210317_omx_mapped_mapped.csv
# Concatenated data for NDRPH9Q with 45263057 rows.
#
# Processing subject folder: NDRPH9Q
# Found 1 relevant CSV file(s): ['NDRPH9Q-MMM666R4P-20210311-20210317_omx_mapped_mapped.csv']
# Processing file: NDRPH9Q-MMM666R4P-20210311-20210317_omx_mapped_mapped.csv
# Concatenated data for NDRPH9Q with 45263057 rows.
# /tmp/ipykernel_943/3900038588.py:110: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   matching_indices = np.where(truth_array == pred_array)[0]
# accuracy:  0.0 num matches:  0
# matches at:  []
# Misalignment of -1178457 between truth and prediction detected!
# Balanced Accuracy for NDRPH9Q: 0.82
# F1 for NDRPH9Q: 0.82
# Precision for NDRPH9Q: 0.68
# Recall for NDRPH9Q: 0.81
# Loading NEP7AP2 labels...
#
# Processing subject folder: NEP7AP2
# No relevant CSV files found in NEP7AP2.
# Loading NXQEXRT labels...
#
# Processing subject folder: NXQEXRT
# Found 1 relevant CSV file(s): ['NXQEXRT-MMMXHXEE6-20210127-20210204_omx_mapped_mapped.csv']
# Processing file: NXQEXRT-MMMXHXEE6-20210127-20210204_omx_mapped_mapped.csv
# Concatenated data for NXQEXRT with 69120000 rows.
#
# Processing subject folder: NXQEXRT
# Found 1 relevant CSV file(s): ['NXQEXRT-MMMXHXEE6-20210127-20210204_omx_mapped_mapped.csv']
# Processing file: NXQEXRT-MMMXHXEE6-20210127-20210204_omx_mapped_mapped.csv
# Concatenated data for NXQEXRT with 69120000 rows.
# /tmp/ipykernel_943/3900038588.py:110: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   matching_indices = np.where(truth_array == pred_array)[0]
# accuracy:  0.0 num matches:  0
# matches at:  []
# Misalignment of -3963190 between truth and prediction detected!
# Balanced Accuracy for NXQEXRT: 0.28
# F1 for NXQEXRT: 0.28
# Precision for NXQEXRT: 0.68
# Recall for NXQEXRT: 0.81
# Loading KXRRZ65 labels...
#
# Processing subject folder: KXRRZ65
# No relevant CSV files found in KXRRZ65.
# Loading NQA4Q9E labels...
#
# Processing subject folder: NQA4Q9E
# Found 2 relevant CSV file(s): ['NQA4Q9E-MMMSDPQCX-20210224-20210302_omx_mapped_mapped.csv', 'NQA4Q9E-MMM7H2TA5-20210303-20210309_omx_mapped_mapped.csv']
# Processing file: NQA4Q9E-MMMSDPQCX-20210224-20210302_omx_mapped_mapped.csv
# Processing file: NQA4Q9E-MMM7H2TA5-20210303-20210309_omx_mapped_mapped.csv
# Concatenated data for NQA4Q9E with 103678000 rows.
#
# Processing subject folder: NQA4Q9E
# Found 2 relevant CSV file(s): ['NQA4Q9E-MMMSDPQCX-20210224-20210302_omx_mapped_mapped.csv', 'NQA4Q9E-MMM7H2TA5-20210303-20210309_omx_mapped_mapped.csv']
# Processing file: NQA4Q9E-MMMSDPQCX-20210224-20210302_omx_mapped_mapped.csv
# Processing file: NQA4Q9E-MMM7H2TA5-20210303-20210309_omx_mapped_mapped.csv
# Concatenated data for NQA4Q9E with 103678000 rows.
# accuracy:  0.9909313451262562 num matches:  102737780
# matches at:  [        0         1         2 ... 103677997 103677998 103677999]
# Balanced Accuracy for NQA4Q9E: 0.72
# F1 for NQA4Q9E: 0.72
# Precision for NQA4Q9E: 0.65
# Recall for NQA4Q9E: 0.79
# Loading GQN7NGG labels...
#
# Processing subject folder: GQN7NGG
# No relevant CSV files found in GQN7NGG.
# Loading N5DP9SQ labels...
#
# Processing subject folder: N5DP9SQ
# Found 2 relevant CSV file(s): ['N5DP9SQ-MMMGGSD5V-20210308-20210314_omx_mapped_mapped.csv', 'N5DP9SQ-MMM266KGE-20210301-20210307_omx_mapped_mapped.csv']
# Processing file: N5DP9SQ-MMMGGSD5V-20210308-20210314_omx_mapped_mapped.csv
# Processing file: N5DP9SQ-MMM266KGE-20210301-20210307_omx_mapped_mapped.csv
# /tmp/ipykernel_943/3900038588.py:54: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Concatenated data for N5DP9SQ with 103680000 rows.
#
# Processing subject folder: N5DP9SQ
# Found 2 relevant CSV file(s): ['N5DP9SQ-MMMGGSD5V-20210308-20210314_omx_mapped_mapped.csv', 'N5DP9SQ-MMM266KGE-20210301-20210307_omx_mapped_mapped.csv']
# Processing file: N5DP9SQ-MMMGGSD5V-20210308-20210314_omx_mapped_mapped.csv
# Processing file: N5DP9SQ-MMM266KGE-20210301-20210307_omx_mapped_mapped.csv
# /tmp/ipykernel_943/3900038588.py:54: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# Concatenated data for N5DP9SQ with 103680000 rows.
# accuracy:  0.94385078125 num matches:  97858449
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for N5DP9SQ: 0.07
# F1 for N5DP9SQ: 0.07
# Precision for N5DP9SQ: 0.06
# Recall for N5DP9SQ: 0.08
# Loading NTDGTR9 labels...
#
# Processing subject folder: NTDGTR9
# Found 2 relevant CSV file(s): ['NTDGTR9-MMMSTF39P-20210301-20210307_omx_mapped_mapped.csv', 'NTDGTR9-MMM4APZZR-20210222-20210228_omx_mapped_mapped.csv']
# Processing file: NTDGTR9-MMMSTF39P-20210301-20210307_omx_mapped_mapped.csv
# Processing file: NTDGTR9-MMM4APZZR-20210222-20210228_omx_mapped_mapped.csv
# Concatenated data for NTDGTR9 with 103680000 rows.
#
# Processing subject folder: NTDGTR9
# Found 2 relevant CSV file(s): ['NTDGTR9-MMMSTF39P-20210301-20210307_omx_mapped_mapped.csv', 'NTDGTR9-MMM4APZZR-20210222-20210228_omx_mapped_mapped.csv']
# Processing file: NTDGTR9-MMMSTF39P-20210301-20210307_omx_mapped_mapped.csv
# Processing file: NTDGTR9-MMM4APZZR-20210222-20210228_omx_mapped_mapped.csv
# Concatenated data for NTDGTR9 with 103680000 rows.
# accuracy:  0.8763301697530864 num matches:  90857912
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for NTDGTR9: 0.10
# F1 for NTDGTR9: 0.10
# Precision for NTDGTR9: 0.08
# Recall for NTDGTR9: 0.13
# Loading NTFR5QE labels...
#
# Processing subject folder: NTFR5QE
# Found 2 relevant CSV file(s): ['NTFR5QE-MMMZA3GVX-20210302-20210308_omx_mapped_mapped.csv', 'NTFR5QE-MMMXHG3EE-20210223-20210301_omx_mapped_mapped.csv']
# Processing file: NTFR5QE-MMMZA3GVX-20210302-20210308_omx_mapped_mapped.csv
# Processing file: NTFR5QE-MMMXHG3EE-20210223-20210301_omx_mapped_mapped.csv
# Concatenated data for NTFR5QE with 103678000 rows.
#
# Processing subject folder: NTFR5QE
# Found 2 relevant CSV file(s): ['NTFR5QE-MMMZA3GVX-20210302-20210308_omx_mapped_mapped.csv', 'NTFR5QE-MMMXHG3EE-20210223-20210301_omx_mapped_mapped.csv']
# Processing file: NTFR5QE-MMMZA3GVX-20210302-20210308_omx_mapped_mapped.csv
# Processing file: NTFR5QE-MMMXHG3EE-20210223-20210301_omx_mapped_mapped.csv
# Concatenated data for NTFR5QE with 103678000 rows.
# accuracy:  0.9097775420050541 num matches:  94323916
# matches at:  [        0         1         2 ... 103677997 103677998 103677999]
# Balanced Accuracy for NTFR5QE: 0.09
# F1 for NTFR5QE: 0.09
# Precision for NTFR5QE: 0.08
# Recall for NTFR5QE: 0.09
# Loading NN4NJ39 labels...
#
# Processing subject folder: NN4NJ39
# No relevant CSV files found in NN4NJ39.
# Loading NJQV67D labels...
#
# Processing subject folder: NJQV67D
# Found 2 relevant CSV file(s): ['NJQV67D-MMMXHXEE6-20210401-20210407_omx_mapped_mapped.csv', 'NJQV67D-MMMCK69HP-20210325-20210331_omx_mapped_mapped.csv']
# Processing file: NJQV67D-MMMXHXEE6-20210401-20210407_omx_mapped_mapped.csv
# Processing file: NJQV67D-MMMCK69HP-20210325-20210331_omx_mapped_mapped.csv
# Concatenated data for NJQV67D with 104040000 rows.
#
# Processing subject folder: NJQV67D
# Found 2 relevant CSV file(s): ['NJQV67D-MMMXHXEE6-20210401-20210407_omx_mapped_mapped.csv', 'NJQV67D-MMMCK69HP-20210325-20210331_omx_mapped_mapped.csv']
# Processing file: NJQV67D-MMMXHXEE6-20210401-20210407_omx_mapped_mapped.csv
# Processing file: NJQV67D-MMMCK69HP-20210325-20210331_omx_mapped_mapped.csv
# Concatenated data for NJQV67D with 104040000 rows.
# accuracy:  0.8586406093810073 num matches:  89332969
# matches at:  [        0         1         2 ... 104039997 104039998 104039999]
# Balanced Accuracy for NJQV67D: 0.20
# F1 for NJQV67D: 0.20
# Precision for NJQV67D: 0.18
# Recall for NJQV67D: 0.23
# Loading N5FA6PR labels...
#
# Processing subject folder: N5FA6PR
# Found 2 relevant CSV file(s): ['N5FA6PR-MMM3XS44K-20210315-20210321_omx_mapped_mapped.csv', 'N5FA6PR-MMM23493T-20210308-20210314_omx_mapped_mapped.csv']
# Processing file: N5FA6PR-MMM3XS44K-20210315-20210321_omx_mapped_mapped.csv
# Processing file: N5FA6PR-MMM23493T-20210308-20210314_omx_mapped_mapped.csv
# Concatenated data for N5FA6PR with 103680000 rows.
#
# Processing subject folder: N5FA6PR
# Found 2 relevant CSV file(s): ['N5FA6PR-MMM3XS44K-20210315-20210321_omx_mapped_mapped.csv', 'N5FA6PR-MMM23493T-20210308-20210314_omx_mapped_mapped.csv']
# Processing file: N5FA6PR-MMM3XS44K-20210315-20210321_omx_mapped_mapped.csv
# Processing file: N5FA6PR-MMM23493T-20210308-20210314_omx_mapped_mapped.csv
# Concatenated data for N5FA6PR with 103680000 rows.
# accuracy:  0.9005618827160494 num matches:  93370256
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for N5FA6PR: 0.11
# F1 for N5FA6PR: 0.11
# Precision for N5FA6PR: 0.10
# Recall for N5FA6PR: 0.12
# Loading NTP5DNA labels...
#
# Processing subject folder: NTP5DNA
# No relevant CSV files found in NTP5DNA.
# Loading NZGPXV4 labels...
#
# Processing subject folder: NZGPXV4
# No relevant CSV files found in NZGPXV4.
# Loading GZJAJ3R labels...
#
# Processing subject folder: GZJAJ3R
# Found 2 relevant CSV file(s): ['GZJAJ3R-MMMQY9EAQ-20210120-20210124_omx_mapped_mapped.csv', 'GZJAJ3R-MMMV2VA6D-20210113-20210117_omx_mapped_mapped.csv']
# Processing file: GZJAJ3R-MMMQY9EAQ-20210120-20210124_omx_mapped_mapped.csv
# Processing file: GZJAJ3R-MMMV2VA6D-20210113-20210117_omx_mapped_mapped.csv
# Concatenated data for GZJAJ3R with 77760000 rows.
#
# Processing subject folder: GZJAJ3R
# Found 2 relevant CSV file(s): ['GZJAJ3R-MMMQY9EAQ-20210120-20210124_omx_mapped_mapped.csv', 'GZJAJ3R-MMMV2VA6D-20210113-20210117_omx_mapped_mapped.csv']
# Processing file: GZJAJ3R-MMMQY9EAQ-20210120-20210124_omx_mapped_mapped.csv
# Processing file: GZJAJ3R-MMMV2VA6D-20210113-20210117_omx_mapped_mapped.csv
# Concatenated data for GZJAJ3R with 77760000 rows.
# accuracy:  0.9007167181069959 num matches:  70039732
# matches at:  [       0        1        2 ... 77759997 77759998 77759999]
# Balanced Accuracy for GZJAJ3R: 0.05
# F1 for GZJAJ3R: 0.05
# Precision for GZJAJ3R: 0.05
# Recall for GZJAJ3R: 0.05
# Loading N7TFS3G labels...
#
# Processing subject folder: N7TFS3G
# Found 2 relevant CSV file(s): ['N7TFS3G-MMMHDKQPY-20210121-20210127_omx_mapped_mapped.csv', 'N7TFS3G-MMMH9S4YP-20210128-20210203_omx_mapped_mapped.csv']
# Processing file: N7TFS3G-MMMHDKQPY-20210121-20210127_omx_mapped_mapped.csv
# Processing file: N7TFS3G-MMMH9S4YP-20210128-20210203_omx_mapped_mapped.csv
# Concatenated data for N7TFS3G with 103680000 rows.
#
# Processing subject folder: N7TFS3G
# Found 2 relevant CSV file(s): ['N7TFS3G-MMMHDKQPY-20210121-20210127_omx_mapped_mapped.csv', 'N7TFS3G-MMMH9S4YP-20210128-20210203_omx_mapped_mapped.csv']
# Processing file: N7TFS3G-MMMHDKQPY-20210121-20210127_omx_mapped_mapped.csv
# Processing file: N7TFS3G-MMMH9S4YP-20210128-20210203_omx_mapped_mapped.csv
# Concatenated data for N7TFS3G with 103680000 rows.
# accuracy:  0.978879581404321 num matches:  101490235
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for N7TFS3G: 0.80
# F1 for N7TFS3G: 0.80
# Precision for N7TFS3G: 0.69
# Recall for N7TFS3G: 0.94
# Loading NKH5P2T labels...
#
# Processing subject folder: NKH5P2T
# No relevant CSV files found in NKH5P2T.
# Loading KFRCHV2 labels...
#
# Processing subject folder: KFRCHV2
# No relevant CSV files found in KFRCHV2.
# Loading NV35KE3 labels...
#
# Processing subject folder: NV35KE3
# No relevant CSV files found in NV35KE3.
# Loading NTKCAYF labels...
#
# Processing subject folder: NTKCAYF
# No relevant CSV files found in NTKCAYF.
# Loading NHZ6JXS labels...
#
# Processing subject folder: NHZ6JXS
# Found 2 relevant CSV file(s): ['NHZ6JXS-MMM26P7YV-20210312-20210318_omx_mapped_mapped.csv', 'NHZ6JXS-MMMGHAXDX-20210305-20210312_omx_mapped_mapped.csv']
# Processing file: NHZ6JXS-MMM26P7YV-20210312-20210318_omx_mapped_mapped.csv
# Processing file: NHZ6JXS-MMMGHAXDX-20210305-20210312_omx_mapped_mapped.csv
# Concatenated data for NHZ6JXS with 53109991 rows.
#
# Processing subject folder: NHZ6JXS
# Found 2 relevant CSV file(s): ['NHZ6JXS-MMM26P7YV-20210312-20210318_omx_mapped_mapped.csv', 'NHZ6JXS-MMMGHAXDX-20210305-20210312_omx_mapped_mapped.csv']
# Processing file: NHZ6JXS-MMM26P7YV-20210312-20210318_omx_mapped_mapped.csv
# Processing file: NHZ6JXS-MMMGHAXDX-20210305-20210312_omx_mapped_mapped.csv
# Concatenated data for NHZ6JXS with 53109991 rows.
# accuracy:  0.8813561463416554 num matches:  46808817
# matches at:  [       0        1        2 ... 53109988 53109989 53109990]
# Balanced Accuracy for NHZ6JXS: 0.13
# F1 for NHZ6JXS: 0.13
# Precision for NHZ6JXS: 0.12
# Recall for NHZ6JXS: 0.14
# Loading NY4RCQC labels...
#
# Processing subject folder: NY4RCQC
# Found 2 relevant CSV file(s): ['NY4RCQC-MMM6SJ6QQ-20210127-20210202_omx_mapped_mapped.csv', 'NY4RCQC-MMM666R4P-20210203-20210209_omx_mapped_mapped.csv']
# Processing file: NY4RCQC-MMM6SJ6QQ-20210127-20210202_omx_mapped_mapped.csv
# Processing file: NY4RCQC-MMM666R4P-20210203-20210209_omx_mapped_mapped.csv
# Concatenated data for NY4RCQC with 70038093 rows.
#
# Processing subject folder: NY4RCQC
# Found 2 relevant CSV file(s): ['NY4RCQC-MMM6SJ6QQ-20210127-20210202_omx_mapped_mapped.csv', 'NY4RCQC-MMM666R4P-20210203-20210209_omx_mapped_mapped.csv']
# Processing file: NY4RCQC-MMM6SJ6QQ-20210127-20210202_omx_mapped_mapped.csv
# Processing file: NY4RCQC-MMM666R4P-20210203-20210209_omx_mapped_mapped.csv
# Concatenated data for NY4RCQC with 70038093 rows.
# accuracy:  0.9881137968733672 num matches:  69205606
# matches at:  [       0        1        2 ... 70038090 70038091 70038092]
# Balanced Accuracy for NY4RCQC: 0.56
# F1 for NY4RCQC: 0.56
# Precision for NY4RCQC: 0.48
# Recall for NY4RCQC: 0.66
# Loading NRE6AG3 labels...
#
# Processing subject folder: NRE6AG3
# Found 2 relevant CSV file(s): ['NRE6AG3-MMMQ3VRXR-20210308-20210314_omx_mapped_mapped.csv', 'NRE6AG3-MMMVZ79SH-20210315-20210321_omx_mapped_mapped.csv']
# Processing file: NRE6AG3-MMMQ3VRXR-20210308-20210314_omx_mapped_mapped.csv
# Processing file: NRE6AG3-MMMVZ79SH-20210315-20210321_omx_mapped_mapped.csv
# Concatenated data for NRE6AG3 with 103680000 rows.
#
# Processing subject folder: NRE6AG3
# Found 2 relevant CSV file(s): ['NRE6AG3-MMMQ3VRXR-20210308-20210314_omx_mapped_mapped.csv', 'NRE6AG3-MMMVZ79SH-20210315-20210321_omx_mapped_mapped.csv']
# Processing file: NRE6AG3-MMMQ3VRXR-20210308-20210314_omx_mapped_mapped.csv
# Processing file: NRE6AG3-MMMVZ79SH-20210315-20210321_omx_mapped_mapped.csv
# Concatenated data for NRE6AG3 with 103680000 rows.
# accuracy:  0.9889062017746914 num matches:  102529795
# matches at:  [        0         1         2 ... 103679997 103679998 103679999]
# Balanced Accuracy for NRE6AG3: 0.83
# F1 for NRE6AG3: 0.83
# Precision for NRE6AG3: 0.79
# Recall for NRE6AG3: 0.87
# 15
